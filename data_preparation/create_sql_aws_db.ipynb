# %%
#Setting up AWS
# !pip3 install ipython-sql pgspecial
#%load_ext sql
# %sql postgresql://admin:ds4a@data-team25.c6tqz0tiazsw.us-east-2.rds.amazonaws.com/project_ds4a

#Create the table for descriptive part of app
# %%sql
CREATE TABLE pro_data
(estu_consecutivo                   varchar(300),
periodo                            integer,
inst_nombre_institucion            varchar(300),
estu_genero                        varchar(300),
estu_areareside                    varchar(300),
estu_pagomatriculabeca             varchar(300),
estu_pagomatriculacredito          varchar(300),
estu_pagomatriculapadres           varchar(300),
estu_comocapacitoexamensb11        varchar(300),
fami_educacionmadre                varchar(300),
fami_estratovivienda               varchar(300),
fami_tieneinternet                 varchar(300),
fami_numlibros                     varchar(300),
estu_dedicacionlecturadiaria       varchar(300),
estu_prgm_academico                varchar(300),
estu_inst_municipio                varchar(300),
estu_inst_departamento             varchar(300),
estu_nucleo_pregrado               varchar(300),
estu_valormatriculauniversidad     varchar(300),
mod_razona_cuantitat_punt         real,
mod_lectura_critica_punt          real,
mod_competen_ciudada_punt         real,
mod_ingles_punt                   real,
mod_comuni_escrita_punt           real)


#Create the table for model part of app
# %%sql
CREATE TABLE pro_data
(estu_consecutivo                   varchar(300),
periodo                            integer,
inst_nombre_institucion            varchar(300),
estu_genero                        varchar(300),
estu_areareside                    varchar(300),
estu_pagomatriculabeca             varchar(300),
estu_pagomatriculacredito          varchar(300),
estu_pagomatriculapadres           varchar(300),
estu_comocapacitoexamensb11        varchar(300),
fami_educacionmadre                varchar(300),
fami_estratovivienda               varchar(300),
fami_tieneinternet                 varchar(300),
fami_numlibros                     varchar(300),
estu_dedicacionlecturadiaria       varchar(300),
estu_prgm_academico                varchar(300),
estu_inst_municipio                varchar(300),
estu_inst_departamento             varchar(300),
estu_nucleo_pregrado               varchar(300),
estu_valormatriculauniversidad     varchar(300),
mod_razona_cuantitat_punt         real,
mod_lectura_critica_punt          real,
mod_competen_ciudada_punt         real,
mod_ingles_punt                   real,
mod_comuni_escrita_punt           real)
